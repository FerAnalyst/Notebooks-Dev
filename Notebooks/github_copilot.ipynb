# %% [markdown]
# # ¿Cómo abrir el agente de copilot en el Editor de Código?
# - Usamos la siguiente combinación de teclas **Ctrl + Alt + I**
# - Se deberá abrir el agente en la parte derecha de tu pantalla:

# %% [markdown]
# ![image.png](attachment:image.png)
