# %% [markdown]
# # ¿Cómo crear y subir un repositorio en Github?
# 1. Guarda todos tus archivos en un único directorio
#
# ![image-2.png](attachment:image-2.png)
#
# 2. Crea un archivo llamado: **.gitignore** y agrega las siguientes lineas:
#
# ```js
# .ipynb_checkpoints/
# __pycache__/
# *.pyc
# .env
# .DS_Store
# Thumbs.db
# ```
#
# 3.
